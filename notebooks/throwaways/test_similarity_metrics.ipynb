# %%
import pandas as pd
import numpy as np
from transformers import AutoModel, AutoTokenizer, AutoModelForSequenceClassification
from sklearn.metrics.pairwise import cosine_similarity, euclidean_distances, manhattan_distances
import warnings
from tqdm import tqdm_notebook as tqdm
from sentence_transformers import SentenceTransformer
import torch
from sklearn.decomposition import TruncatedSVD


class Embedding:
    """
    A class to generate embeddings for startups and industries using specified language models and pooling methods.
    """

    def __init__(self, startups, industries, llm='bert', pool='max', sentence_transformer=False, sent='sentence-transformers/all-MiniLM-L6-v2',
                 both=False):

        """
        Initializes the Embedding class with specified language models and pooling methods.

        :param startups: DataFrame containing startup data with 'id' and 'cb_description' columns
        :param industries: DataFrame containing industry data with 'id' and 'keywords' columns
        :param llm: string, the language model to use for generating embeddings, default is 'bert'
        :param pool: string, the pooling method to use for generating embeddings, default is 'max'
        :param sentence_transformer: bool, whether to use a sentence transformer model, default is False
        """

        self.startups = startups
        self.industries = industries
        self.sentence_transformer = sentence_transformer
        self.pool = pool
        self.both = both
        self.llm = {
            'bert': 'bert-base-uncased',
            'gpt2': 'gpt2',
            'gpt': 'openai-gpt',
            'roberta': 'roberta-base',
            'distilbert': 'distilbert-base-uncased',
            'xlnet': 'xlnet-base-uncased',
            'electra': 'google/electra-base-discriminator',
            'industry_classifier': 'sampathkethineedi/industry-classification'
        }
        self.__initialize_models(both, llm, sentence_transformer, sent)
        self.svd = TruncatedSVD(n_components=384)

    def __initialize_models(self, both, llm, sentence_transformer, sent):

        if not both:
            if not sentence_transformer:
                self.model = AutoModel.from_pretrained(self.llm[llm])
                self.tokenizer = AutoTokenizer.from_pretrained(self.llm[llm])
            else:
                self.model = SentenceTransformer(sent)
        else:
            self.model = AutoModel.from_pretrained(self.llm[llm])
            self.tokenizer = AutoTokenizer.from_pretrained(self.llm[llm])
            self.sentence_transformer = SentenceTransformer(sent)

    def generate_embeddings(self, startup=True):
        """
        Generates embeddings for startups or industries using the specified language model and pooling method.

        :param startup: bool, if True, generates embeddings for startups, if False, generates embeddings for industries
        :return: DataFrame with generated embeddings merged with the original input DataFrame
        """
        texts = self.startups if startup else self.industries
        embeddings_list = []

        for i, row in tqdm(texts.iterrows()):
            id = row['id']
            if startup:
                description = row['cb_description']
            else:
                description = row['keywords']
            if self.sentence_transformer:
                embeddings = self.model.encode(description)
            else:
                inputs = self.tokenizer.encode_plus(description, return_tensors="pt", truncation=True, padding="max_length", max_length=60)
                outputs = self.model(**inputs)
                last_hidden_states = outputs.last_hidden_state
                embeddings = self.pooling(last_hidden_states)

            embeddings_list.append({'id': id, 'embeddings': embeddings.tolist()})

        embeddings_df = pd.DataFrame(embeddings_list)
        merged_df = pd.merge(texts, embeddings_df, on='id', how='left')

        if startup:
            self.startups = merged_df
        else:
            self.industries = merged_df

        return merged_df

    def assign_industry(self, num_labels=3, metric='cosine'):
        """
        Assigns top industries to startups based on their similarity to the industry embeddings.

        :param num_labels: int, the number of top industries to assign to each startup, default is 3
        :param metric: string, the similarity metric to use, default is 'cosine'
        :return: list of lists containing dictionaries with assigned industries and their similarity scores
        """
        if metric not in ['cosine', 'euclidean', 'manhattan']:
            raise ValueError("metric must be one of 'cosine', 'euclidean', 'manhattan'")

        self.assigned_industries = []
        for startup_embedding in self.startups['embeddings']:
            startup_embedding = np.array(startup_embedding).flatten()
            industry_embeddings = np.array([np.array(x).flatten() for x in self.industries['embeddings']])

            if metric == 'cosine':
                scores = cosine_similarity([startup_embedding], industry_embeddings)[0]
                top_industry_indices = np.argsort(scores)[-num_labels:][::-1]
            elif metric == 'euclidean':
                scores = euclidean_distances([startup_embedding], industry_embeddings)[0]
                top_industry_indices = np.argsort(scores)[:num_labels]
            elif metric == 'manhattan':
                scores = manhattan_distances([startup_embedding], industry_embeddings)[0]
                top_industry_indices = np.argsort(scores)[:num_labels]
            else:
                raise ValueError("metric must be one of 'cosine', 'euclidean', 'manhattan'")

            # Calculate confidence scores for the top industries
            top_scores = [scores[index] for index in top_industry_indices]
            confidence_industry_1, confidence_industry_2, confidence_industry_3 = self.__calculate_confidence(*top_scores)

            # Include confidence scores in the top_industries dictionaries
            top_industries = [{'industry': self.industries.iloc[index]['industry'], 'score': scores[index], 'confidence': confidence}
                              for index, confidence in zip(top_industry_indices, [confidence_industry_1, confidence_industry_2, confidence_industry_3])]

            self.assigned_industries.append(top_industries)

        return self.assigned_industries


    def pooling(self, embeddings_tensor):

        if self.pool == 'max':
            pooled_embeds = torch.max(embeddings_tensor, dim=1).values
        elif self.pool == 'avg':
            pooled_embeds = torch.mean(embeddings_tensor, dim=1)
        elif self.pool == 'concat':
            max_pooling = torch.max(embeddings_tensor, dim=1).values
            average_pooling = torch.mean(embeddings_tensor, dim=1)
            pooled_embeds = torch.cat((max_pooling, average_pooling), dim=1)
        else:
            raise ValueError('pool must be either max, avg, or concat')
        return pooled_embeds.detach().numpy()



    def update_dataframe(self):
        """
        Updates the startup and industry DataFrames with assigned industries and their similarity scores.

        :return: DataFrame with updated startups data
        """
        df = self.startups.copy()
        max_industries = max([len(x) for x in self.assigned_industries])

        for i in range(max_industries):
            df[f'industry{i + 1}'] = [x[i]['industry'] if i < len(x) else None for x in self.assigned_industries]
            df[f'score{i + 1}'] = [x[i]['score'].round(3) if i < len(x) else None for x in self.assigned_industries]

        #df.drop(columns=['embeddings'], inplace=True)
        #self.industries.drop(columns=['embeddings'], inplace=True)

        return df

    def __calculate_confidence(self, *scores):
        """
        Calculates the confidence of the assigned industries based on the similarity scores.

        :param scores: list of similarity scores
        :return: float, the confidence score
        """
        confidence_industry_1 = scores[0]/sum(scores)
        confidence_industry_2 = scores[1]/sum(scores)
        confidence_industry_3 = scores[2]/sum(scores)

        return confidence_industry_1, confidence_industry_2, confidence_industry_3

# %%
startups = pd.read_csv(r'C:\Users\imran\DataspellProjects\WalidCase\data\processed\startups_clean_noents_1560.csv')
startups = startups[['id', 'name', 'cb_description']]
industries = pd.read_csv(r'C:\Users\imran\DataspellProjects\WalidCase\data\processed\no_crm_GPT4_generated_keywords.csv')

# %%
industries['id'] = industries.index

# %%
embedding = Embedding(startups.head(50), industries, llm='bert', pool='max')
embedding.generate_embeddings(startup=True)
embedding.generate_embeddings(startup=False)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# C:\Users\imran\AppData\Local\Temp\ipykernel_11444\2939165115.py:71: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i, row in tqdm(texts.iterrows()):
# 0it [00:00, ?it/s]
# C:\Users\imran\AppData\Local\Temp\ipykernel_11444\2939165115.py:71: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i, row in tqdm(texts.iterrows()):
# 0it [00:00, ?it/s]
#                    industry  \
# 0                  Telecoms
# 1                    Mobile
# 2            Communications
# 3    Network Infrastructure
# 4               5G Networks
# ..                      ...
# 112             Video/Audio
# 113                Genomics
# 114               Longevity
# 115          Gut Microbiome
# 116           Life Sciences
#
#                                               keywords   id  \
# 0    carrier services, satellite communication, fix...    0
# 1    mobile applications, mobile devices, mobile op...    1
# 2    real-time communication, chat applications, vi...    2
# 3    content delivery network, network function vir...    3
# 4    5G radio access network, millimeter wave, 5G s...    4
# ..                                                 ...  ...
# 112  media production, video platforms, audio engin...  112
# 113  functional genomics, gene expression, epigenom...  113
# 114  aging biology, lifespan extension, rejuvenatio...  114
# 115  intestinal microbiota, intestinal ecology, gut...  115
# 116  drug discovery, therapeutics, biotechnology, p...  116
#
#                                             embeddings
# 0    [[1.6293150186538696, 0.9383618235588074, 1.07...
# 1    [[0.7876855134963989, 1.2005103826522827, 1.30...
# 2    [[0.7855498790740967, 0.6936728954315186, 1.23...
# 3    [[0.7913244366645813, 0.44820863008499146, 1.1...
# 4    [[0.38631683588027954, 0.4769960045814514, 0.9...
# ..                                                 ...
# 112  [[1.0657232999801636, 0.7541917562484741, 1.05...
# 113  [[1.0262608528137207, 0.6551767587661743, 1.40...
# 114  [[1.128448486328125, 0.9876158237457275, 0.855...
# 115  [[0.8957403898239136, 0.845739483833313, 0.607...
# 116  [[1.0813782215118408, 1.2989277839660645, 0.92...
#
# [117 rows x 4 columns]

# %%
assigned_industries_cosine = embedding.assign_industry(num_labels=3, metric='cosine')
df_cosine = embedding.update_dataframe()

# %%
df_cosine
# Out:
#        id                  name  \
# 0    1820                 0xKYC
# 1    3640          10X-Genomics
# 2    9594               111Skin
# 3     473               1stdibs
# 4    7956                 1v1Me
# 5    9457         21sportsgroup
# 6     917             24Symbols
# 7    5470                  2GIS
# 8    5958     352-Medical-Group
# 9    4004          365-Response
# 10   5635             365Scores
# 11   4797                  3Box
# 12   8364           3D-Robotics
# 13   3918            3sun-Group
# 14   1767       40-Partners-Ltd
# 15   1351                 42Lab
# 16   8307         4-Antibody-AG
# 17   8780               4energy
# 18   6524                 5Mins
# 19   1504              7bridges
# 20   4084              7digital
# 21    432            7TM-Pharma
# 22   3403                  8fit
# 23     28         8tracks-Radio
# 24   8509                   a55
# 25   1382             AarogyaAI
# 26   5266                Abacum
# 27    258             Abacus.AI
# 28   3853        Abacus-e-Media
# 29   6113           ABA-English
# 30  10663                  ABAX
# 31   6511               Abcodia
# 32   9786                  Abhi
# 33   3255        ABK-Biomedical
# 34   5750                Ablynx
# 35   3527    Abogen-Biosciences
# 36   7990               Abokado
# 37   3174           AbsolutData
# 38   3436         Acacia-Pharma
# 39   4672           ACAL-Energy
# 40    739  Accelerated-Payments
# 41   4924           AccelerComm
# 42   6388           Access-Bank
# 43   6483         AccessFintech
# 44  10138   Access-Intelligence
# 45   3427     Accuri-Cytometers
# 46  10601           Accutrainee
# 47   8817              AccuVein
# 48   7247           Acea-Health
# 49   6553        Acesion-Pharma
#
#                                        cb_description              industry1  \
# 0   modular knowledge system identity credential m...          Generative AI
# 1   create revolutionary dna sequence technology h...               Genomics
# 2   commit positive luxury skincare push boundary ...                Fashion
# 3   internet company offer marketplace rare desira...             E-commerce
# 4   application allow user play match favorite vid...                Esports
# 5   online sport good retailer offer selection run...              Longevity
# 6   solution read digital book read device interne...           Data Centers
# 7   international technology company develop servi...        Sharing Economy
# 8   local organisation trust healthcare profession...             Healthcare
# 9   response unique software service organisation ...     Autonomous Driving
# 10  cross platform application enable user create ...                Esports
# 11  storage simple secure private design store dat...           Data Storage
# 12  make advanced drone technology easily accessib...     Autonomous Driving
# 13  limited subsidiary provide hydraulic control i...              InsurTech
# 14  produce talent broadcaster brand short form fe...          Entertainment
# 15  modular portable affordable biotech laboratory...     Autonomous Driving
# 16  develop human antibody drug discovery platform...         Gut Microbiome
# 17  locate nottingham produce cool solution delive...                    IoT
# 18  s gamified learn platform design help employee...          Generative AI
# 19  smart logistic platform deliver visibility con...     Autonomous Driving
# 20  global leader end end digital music solution c...     Autonomous Driving
# 21  biotech company discover develop drug primary ...         Gut Microbiome
# 22  app help build healthy habit life simple solut...     Autonomous Driving
# 23  internet radio social network streams user cur...        Creator Economy
# 24  developer financial underwriting platform offe...                FinTech
# 25  aarogyaai artificial intelligence base softwar...              Longevity
# 26  abacum saas help finance team deliver business...              InsurTech
# 27  artificial intelligence research cloud service...     Autonomous Driving
# 28  abacus e medium bring digital expertise indust...        Creator Economy
# 29  lead learn student worldwide headquarter talen...          Generative AI
# 30  developer supplier tracker system software tec...     Autonomous Driving
# 31  biotechnology company focus discovery validati...              Longevity
# 32  abhi financial wellness platform provide emplo...              InsurTech
# 33  combine clinical market biomaterial specialize...                MedTech
# 34  ablynx biopharmaceutical company engage discov...              Longevity
# 35  abogen bioscience discovery stage biotechnolog...              Longevity
# 36  own operate chain food bar restaurant offer su...        Food & Beverage
# 37  consult orient analytic research firm number c...  Business Intelligence
# 38  pharmaceutical company discover develop suppor...              Longevity
# 39  developer system module consumable chemical ra...     Autonomous Driving
# 40  accelerated payment enable sme expand grow all...        Sharing Economy
# 41  accelercomm exciting semiconductor ip core com...            5G Networks
# 42  provide banking product service individual bus...             E-commerce
# 43  accessfintech offer risk management service ba...              InsurTech
# 44  access intelligence b b medium information com...         Gut Microbiome
# 45  found address compelling need life scientist l...     Autonomous Driving
# 46  accutrainee found run solicitor understand leg...              LegalTech
# 47  accuvein specialize vein visualization technol...            Health Tech
# 48  acea health digital company develop applicatio...            Health Tech
# 49  acesion developer medical drug design treatmen...              Longevity
#
#     score1              industry2  score2              industry3  score3
# 0    0.920              InsurTech   0.919                RegTech   0.918
# 1    0.918  Business Intelligence   0.913              Longevity   0.907
# 2    0.904         Carbon Removal   0.897        Sharing Economy   0.895
# 3    0.904                Fashion   0.900        Creator Economy   0.899
# 4    0.891                 Gaming   0.890        Creator Economy   0.889
# 5    0.910              LegalTech   0.909              InsurTech   0.908
# 6    0.903         Connected Home   0.903         Connected Life   0.902
# 7    0.908               PropTech   0.907        Creator Economy   0.906
# 8    0.902            Health Tech   0.901             Death Tech   0.894
# 9    0.918    Data Infrastructure   0.915                    IoT   0.915
# 10   0.906     Autonomous Driving   0.903  Business Intelligence   0.903
# 11   0.915    Data Infrastructure   0.913             Blockchain   0.909
# 12   0.926  Business Intelligence   0.922                   Web3   0.921
# 13   0.916         Carbon Capture   0.915              LegalTech   0.914
# 14   0.887        Creator Economy   0.882               PropTech   0.879
# 15   0.913              Longevity   0.913         Connected Home   0.910
# 16   0.938              Longevity   0.934          Life Sciences   0.933
# 17   0.900               PropTech   0.898           Data Centers   0.897
# 18   0.919                MarTech   0.917     Autonomous Driving   0.915
# 19   0.923    Infrastructure Tech   0.921                   Web3   0.917
# 20   0.922        Creator Economy   0.921    Infrastructure Tech   0.920
# 21   0.937              Longevity   0.931     Autonomous Driving   0.922
# 22   0.907  Happiness & Wellbeing   0.906              Longevity   0.906
# 23   0.903        Social Networks   0.901                Esports   0.892
# 24   0.924  Business Intelligence   0.919              InsurTech   0.917
# 25   0.929          Generative AI   0.925         Gut Microbiome   0.924
# 26   0.924                FinTech   0.921     Autonomous Driving   0.921
# 27   0.916           Productivity   0.916  Business Intelligence   0.913
# 28   0.909    Infrastructure Tech   0.907               PropTech   0.906
# 29   0.915     Autonomous Driving   0.914         Gut Microbiome   0.914
# 30   0.908                MarTech   0.905             Automotive   0.905
# 31   0.916            Health Tech   0.914                FinTech   0.914
# 32   0.916           Productivity   0.915             Death Tech   0.913
# 33   0.914         Gut Microbiome   0.914              Longevity   0.914
# 34   0.929         Gut Microbiome   0.926          Life Sciences   0.924
# 35   0.922         Gut Microbiome   0.922          Life Sciences   0.921
# 36   0.910        Sharing Economy   0.907                Fashion   0.906
# 37   0.912                MarTech   0.906        Developer Tools   0.901
# 38   0.926         Gut Microbiome   0.923           Psychedelics   0.921
# 39   0.921                    IoT   0.920    Infrastructure Tech   0.918
# 40   0.923             E-commerce   0.920                MarTech   0.915
# 41   0.927     Autonomous Driving   0.926                 Crypto   0.923
# 42   0.906               Payments   0.901               Telecoms   0.897
# 43   0.922     Autonomous Driving   0.919                FinTech   0.918
# 44   0.905               Telecoms   0.905                RegTech   0.905
# 45   0.910  Business Intelligence   0.909              Longevity   0.909
# 46   0.910         Future of Work   0.904              InsurTech   0.903
# 47   0.921              Longevity   0.921              InsurTech   0.919
# 48   0.920              InsurTech   0.918               PropTech   0.914
# 49   0.929         Gut Microbiome   0.929     Autonomous Driving   0.921

# %%
df_cosine.drop(columns=['embeddings'], inplace=True)

# %%
df_cosine
# Out:
#        id                  name  \
# 0    1820                 0xKYC
# 1    3640          10X-Genomics
# 2    9594               111Skin
# 3     473               1stdibs
# 4    7956                 1v1Me
# 5    9457         21sportsgroup
# 6     917             24Symbols
# 7    5470                  2GIS
# 8    5958     352-Medical-Group
# 9    4004          365-Response
# 10   5635             365Scores
# 11   4797                  3Box
# 12   8364           3D-Robotics
# 13   3918            3sun-Group
# 14   1767       40-Partners-Ltd
# 15   1351                 42Lab
# 16   8307         4-Antibody-AG
# 17   8780               4energy
# 18   6524                 5Mins
# 19   1504              7bridges
# 20   4084              7digital
# 21    432            7TM-Pharma
# 22   3403                  8fit
# 23     28         8tracks-Radio
# 24   8509                   a55
# 25   1382             AarogyaAI
# 26   5266                Abacum
# 27    258             Abacus.AI
# 28   3853        Abacus-e-Media
# 29   6113           ABA-English
# 30  10663                  ABAX
# 31   6511               Abcodia
# 32   9786                  Abhi
# 33   3255        ABK-Biomedical
# 34   5750                Ablynx
# 35   3527    Abogen-Biosciences
# 36   7990               Abokado
# 37   3174           AbsolutData
# 38   3436         Acacia-Pharma
# 39   4672           ACAL-Energy
# 40    739  Accelerated-Payments
# 41   4924           AccelerComm
# 42   6388           Access-Bank
# 43   6483         AccessFintech
# 44  10138   Access-Intelligence
# 45   3427     Accuri-Cytometers
# 46  10601           Accutrainee
# 47   8817              AccuVein
# 48   7247           Acea-Health
# 49   6553        Acesion-Pharma
#
#                                        cb_description              industry1  \
# 0   modular knowledge system identity credential m...                RegTech
# 1   create revolutionary dna sequence technology h...               Genomics
# 2   commit positive luxury skincare push boundary ...                 Beauty
# 3   internet company offer marketplace rare desira...             E-commerce
# 4   application allow user play match favorite vid...        Social Networks
# 5   online sport good retailer offer selection run...                Fashion
# 6   solution read digital book read device interne...                 Mobile
# 7   international technology company develop servi...                 Mobile
# 8   local organisation trust healthcare profession...             Healthcare
# 9   response unique software service organisation ...           Productivity
# 10  cross platform application enable user create ...                Esports
# 11  storage simple secure private design store dat...           Data Storage
# 12  make advanced drone technology easily accessib...  Business Intelligence
# 13  limited subsidiary provide hydraulic control i...         Industrial IoT
# 14  produce talent broadcaster brand short form fe...          Entertainment
# 15  modular portable affordable biotech laboratory...               Hardware
# 16  develop human antibody drug discovery platform...          Life Sciences
# 17  locate nottingham produce cool solution delive...              GreenTech
# 18  s gamified learn platform design help employee...                 Gaming
# 19  smart logistic platform deliver visibility con...          Supply Chains
# 20  global leader end end digital music solution c...                  Media
# 21  biotech company discover develop drug primary ...          Life Sciences
# 22  app help build healthy habit life simple solut...  Happiness & Wellbeing
# 23  internet radio social network streams user cur...        Creator Economy
# 24  developer financial underwriting platform offe...                   DeFi
# 25  aarogyaai artificial intelligence base softwar...            Health Tech
# 26  abacum saas help finance team deliver business...           Productivity
# 27  artificial intelligence research cloud service...       Physical Storage
# 28  abacus e medium bring digital expertise indust...        Creator Economy
# 29  lead learn student worldwide headquarter talen...                 EdTech
# 30  developer supplier tracker system software tec...          Supply Chains
# 31  biotechnology company focus discovery validati...               Genomics
# 32  abhi financial wellness platform provide emplo...        Human Resources
# 33  combine clinical market biomaterial specialize...                MedTech
# 34  ablynx biopharmaceutical company engage discov...          Life Sciences
# 35  abogen bioscience discovery stage biotechnolog...          Life Sciences
# 36  own operate chain food bar restaurant offer su...        Food & Beverage
# 37  consult orient analytic research firm number c...             Automation
# 38  pharmaceutical company discover develop suppor...  Happiness & Wellbeing
# 39  developer system module consumable chemical ra...              GreenTech
# 40  accelerated payment enable sme expand grow all...   Economic Empowerment
# 41  accelercomm exciting semiconductor ip core com...            5G Networks
# 42  provide banking product service individual bus...               Payments
# 43  accessfintech offer risk management service ba...                RegTech
# 44  access intelligence b b medium information com...               Telecoms
# 45  found address compelling need life scientist l...          Life Sciences
# 46  accutrainee found run solicitor understand leg...              LegalTech
# 47  accuvein specialize vein visualization technol...                MedTech
# 48  acea health digital company develop applicatio...            Health Tech
# 49  acesion developer medical drug design treatmen...                   DeFi
#
#     score1              industry2  score2               industry3  score3
# 0    0.359                   DeFi   0.339                 InfoSec   0.325
# 1    0.438          Life Sciences   0.306               Deep Tech   0.262
# 2    0.483                SexTech   0.337   Happiness & Wellbeing   0.328
# 3    0.443                Fashion   0.430                  Beauty   0.397
# 4    0.295                 Gaming   0.279           Entertainment   0.260
# 5    0.441             E-commerce   0.389                  Retail   0.355
# 6    0.221                 EdTech   0.219                Telecoms   0.172
# 7    0.419               Telecoms   0.412             Health Tech   0.401
# 8    0.519            Health Tech   0.433               InsurTech   0.331
# 9    0.312       Circular Economy   0.304          Future of Work   0.297
# 10   0.406          Entertainment   0.358          Communications   0.311
# 11   0.516       Physical Storage   0.379         Data Management   0.373
# 12   0.434           Productivity   0.419          Industrial IoT   0.418
# 13   0.320               Telecoms   0.317                 RegTech   0.311
# 14   0.334        Creator Economy   0.324                  Gaming   0.287
# 15   0.346                MedTech   0.339                  Design   0.337
# 16   0.401               Genomics   0.331                 MedTech   0.324
# 17   0.389      Energy Efficiency   0.366    Climate & Clean Tech   0.365
# 18   0.401         Future of Work   0.398         Creator Economy   0.388
# 19   0.422         Industrial IoT   0.393        Circular Economy   0.363
# 20   0.448               Telecoms   0.437     Data Infrastructure   0.427
# 21   0.360         Gut Microbiome   0.347                Genomics   0.281
# 22   0.420       Sport & Wellness   0.381              Healthcare   0.321
# 23   0.434        Social Networks   0.388           Entertainment   0.331
# 24   0.524                RegTech   0.500                 FinTech   0.494
# 25   0.367             Healthcare   0.335           Life Sciences   0.317
# 26   0.397  Business Intelligence   0.379           Social Impact   0.377
# 27   0.364           Data Centers   0.349              Automation   0.346
# 28   0.487                 Design   0.460                   Media   0.456
# 29   0.401   Economic Empowerment   0.284            Productivity   0.280
# 30   0.458              Logistics   0.434             Procurement   0.429
# 31   0.382          Life Sciences   0.373                 RegTech   0.360
# 32   0.384   Economic Empowerment   0.382                 FemTech   0.317
# 33   0.269             Healthcare   0.221           Life Sciences   0.209
# 34   0.369                   Nano   0.333               Deep Tech   0.299
# 35   0.425               Genomics   0.366              Healthcare   0.267
# 36   0.330       Circular Economy   0.286           Supply Chains   0.253
# 37   0.430         Industrial IoT   0.424   Business Intelligence   0.399
# 38   0.390             Healthcare   0.358               Nutrition   0.336
# 39   0.407   Climate & Clean Tech   0.393        Circular Economy   0.377
# 40   0.422        Sharing Economy   0.390                 FinTech   0.387
# 41   0.328               Telecoms   0.285  Network Infrastructure   0.245
# 42   0.449                FinTech   0.424              E-commerce   0.395
# 43   0.416                   DeFi   0.413                 FinTech   0.412
# 44   0.389                RegTech   0.386          Industrial IoT   0.374
# 45   0.349                MedTech   0.330                Genomics   0.304
# 46   0.439              InsurTech   0.274             Procurement   0.250
# 47   0.459            Health Tech   0.402              Healthcare   0.377
# 48   0.429             Healthcare   0.401                 InfoSec   0.367
# 49   0.271             Healthcare   0.270               Nutrition   0.254

# %%
assigned_industries_cosine.drop(columns=['embeddings'], inplace=True)
assigned_industries_euclidean.drop(columns=['embeddings'], inplace=True)
assigned_industries_manhattan.drop(columns=['embeddings'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 assigned_industries_cosine.drop(columns=['embeddings'], inplace=True)
#
# AttributeError: 'list' object has no attribute 'drop'

# %%
#merge all three dataframes on id and keep only the columns with industries and scores
assigned_industries = assigned_industries_cosine.merge(assigned_industries_euclidean, on='id', how='left')
assigned_industries = assigned_industries.merge(assigned_industries_manhattan, on='id', how='left')
assigned_industries
# Out:
#        id                name_x  \
# 0    1820                 0xKYC
# 1    3640          10X-Genomics
# 2    9594               111Skin
# 3     473               1stdibs
# 4    7956                 1v1Me
# 5    9457         21sportsgroup
# 6     917             24Symbols
# 7    5470                  2GIS
# 8    5958     352-Medical-Group
# 9    4004          365-Response
# 10   5635             365Scores
# 11   4797                  3Box
# 12   8364           3D-Robotics
# 13   3918            3sun-Group
# 14   1767       40-Partners-Ltd
# 15   1351                 42Lab
# 16   8307         4-Antibody-AG
# 17   8780               4energy
# 18   6524                 5Mins
# 19   1504              7bridges
# 20   4084              7digital
# 21    432            7TM-Pharma
# 22   3403                  8fit
# 23     28         8tracks-Radio
# 24   8509                   a55
# 25   1382             AarogyaAI
# 26   5266                Abacum
# 27    258             Abacus.AI
# 28   3853        Abacus-e-Media
# 29   6113           ABA-English
# 30  10663                  ABAX
# 31   6511               Abcodia
# 32   9786                  Abhi
# 33   3255        ABK-Biomedical
# 34   5750                Ablynx
# 35   3527    Abogen-Biosciences
# 36   7990               Abokado
# 37   3174           AbsolutData
# 38   3436         Acacia-Pharma
# 39   4672           ACAL-Energy
# 40    739  Accelerated-Payments
# 41   4924           AccelerComm
# 42   6388           Access-Bank
# 43   6483         AccessFintech
# 44  10138   Access-Intelligence
# 45   3427     Accuri-Cytometers
# 46  10601           Accutrainee
# 47   8817              AccuVein
# 48   7247           Acea-Health
# 49   6553        Acesion-Pharma
#
#                                      cb_description_x            industry1_x  \
# 0   modular knowledge system identity credential m...                RegTech
# 1   create revolutionary dna sequence technology h...               Genomics
# 2   commit positive luxury skincare push boundary ...                 Beauty
# 3   internet company offer marketplace rare desira...             E-commerce
# 4   application allow user play match favorite vid...        Social Networks
# 5   online sport good retailer offer selection run...                Fashion
# 6   solution read digital book read device interne...                 Mobile
# 7   international technology company develop servi...                 Mobile
# 8   local organisation trust healthcare profession...             Healthcare
# 9   response unique software service organisation ...           Productivity
# 10  cross platform application enable user create ...                Esports
# 11  storage simple secure private design store dat...           Data Storage
# 12  make advanced drone technology easily accessib...  Business Intelligence
# 13  limited subsidiary provide hydraulic control i...         Industrial IoT
# 14  produce talent broadcaster brand short form fe...          Entertainment
# 15  modular portable affordable biotech laboratory...               Hardware
# 16  develop human antibody drug discovery platform...          Life Sciences
# 17  locate nottingham produce cool solution delive...              GreenTech
# 18  s gamified learn platform design help employee...                 Gaming
# 19  smart logistic platform deliver visibility con...          Supply Chains
# 20  global leader end end digital music solution c...                  Media
# 21  biotech company discover develop drug primary ...          Life Sciences
# 22  app help build healthy habit life simple solut...  Happiness & Wellbeing
# 23  internet radio social network streams user cur...        Creator Economy
# 24  developer financial underwriting platform offe...                   DeFi
# 25  aarogyaai artificial intelligence base softwar...            Health Tech
# 26  abacum saas help finance team deliver business...           Productivity
# 27  artificial intelligence research cloud service...       Physical Storage
# 28  abacus e medium bring digital expertise indust...        Creator Economy
# 29  lead learn student worldwide headquarter talen...                 EdTech
# 30  developer supplier tracker system software tec...          Supply Chains
# 31  biotechnology company focus discovery validati...               Genomics
# 32  abhi financial wellness platform provide emplo...        Human Resources
# 33  combine clinical market biomaterial specialize...                MedTech
# 34  ablynx biopharmaceutical company engage discov...          Life Sciences
# 35  abogen bioscience discovery stage biotechnolog...          Life Sciences
# 36  own operate chain food bar restaurant offer su...        Food & Beverage
# 37  consult orient analytic research firm number c...             Automation
# 38  pharmaceutical company discover develop suppor...  Happiness & Wellbeing
# 39  developer system module consumable chemical ra...              GreenTech
# 40  accelerated payment enable sme expand grow all...   Economic Empowerment
# 41  accelercomm exciting semiconductor ip core com...            5G Networks
# 42  provide banking product service individual bus...               Payments
# 43  accessfintech offer risk management service ba...                RegTech
# 44  access intelligence b b medium information com...               Telecoms
# 45  found address compelling need life scientist l...          Life Sciences
# 46  accutrainee found run solicitor understand leg...              LegalTech
# 47  accuvein specialize vein visualization technol...                MedTech
# 48  acea health digital company develop applicatio...            Health Tech
# 49  acesion developer medical drug design treatmen...                   DeFi
#
#     score1_x            industry2_x  score2_x             industry3_x  \
# 0      0.359                   DeFi     0.339                 InfoSec
# 1      0.438          Life Sciences     0.306               Deep Tech
# 2      0.483                SexTech     0.337   Happiness & Wellbeing
# 3      0.443                Fashion     0.430                  Beauty
# 4      0.295                 Gaming     0.279           Entertainment
# 5      0.441             E-commerce     0.389                  Retail
# 6      0.221                 EdTech     0.219                Telecoms
# 7      0.419               Telecoms     0.412             Health Tech
# 8      0.519            Health Tech     0.433               InsurTech
# 9      0.312       Circular Economy     0.304          Future of Work
# 10     0.406          Entertainment     0.358          Communications
# 11     0.516       Physical Storage     0.379         Data Management
# 12     0.434           Productivity     0.419          Industrial IoT
# 13     0.320               Telecoms     0.317                 RegTech
# 14     0.334        Creator Economy     0.324                  Gaming
# 15     0.346                MedTech     0.339                  Design
# 16     0.401               Genomics     0.331                 MedTech
# 17     0.389      Energy Efficiency     0.366    Climate & Clean Tech
# 18     0.401         Future of Work     0.398         Creator Economy
# 19     0.422         Industrial IoT     0.393        Circular Economy
# 20     0.448               Telecoms     0.437     Data Infrastructure
# 21     0.360         Gut Microbiome     0.347                Genomics
# 22     0.420       Sport & Wellness     0.381              Healthcare
# 23     0.434        Social Networks     0.388           Entertainment
# 24     0.524                RegTech     0.500                 FinTech
# 25     0.367             Healthcare     0.335           Life Sciences
# 26     0.397  Business Intelligence     0.379           Social Impact
# 27     0.364           Data Centers     0.349              Automation
# 28     0.487                 Design     0.460                   Media
# 29     0.401   Economic Empowerment     0.284            Productivity
# 30     0.458              Logistics     0.434             Procurement
# 31     0.382          Life Sciences     0.373                 RegTech
# 32     0.384   Economic Empowerment     0.382                 FemTech
# 33     0.269             Healthcare     0.221           Life Sciences
# 34     0.369                   Nano     0.333               Deep Tech
# 35     0.425               Genomics     0.366              Healthcare
# 36     0.330       Circular Economy     0.286           Supply Chains
# 37     0.430         Industrial IoT     0.424   Business Intelligence
# 38     0.390             Healthcare     0.358               Nutrition
# 39     0.407   Climate & Clean Tech     0.393        Circular Economy
# 40     0.422        Sharing Economy     0.390                 FinTech
# 41     0.328               Telecoms     0.285  Network Infrastructure
# 42     0.449                FinTech     0.424              E-commerce
# 43     0.416                   DeFi     0.413                 FinTech
# 44     0.389                RegTech     0.386          Industrial IoT
# 45     0.349                MedTech     0.330                Genomics
# 46     0.439              InsurTech     0.274             Procurement
# 47     0.459            Health Tech     0.402              Healthcare
# 48     0.429             Healthcare     0.401                 InfoSec
# 49     0.271             Healthcare     0.270               Nutrition
#
#     score3_x                name_y  ...             industry3_y score3_y  \
# 0      0.325                 0xKYC  ...                 InfoSec    1.162
# 1      0.262          10X-Genomics  ...               Deep Tech    1.215
# 2      0.328               111Skin  ...   Happiness & Wellbeing    1.159
# 3      0.397               1stdibs  ...                  Beauty    1.098
# 4      0.260                 1v1Me  ...           Entertainment    1.216
# 5      0.355         21sportsgroup  ...                  Retail    1.136
# 6      0.172             24Symbols  ...                Telecoms    1.287
# 7      0.401                  2GIS  ...             Health Tech    1.094
# 8      0.331     352-Medical-Group  ...               InsurTech    1.157
# 9      0.297          365-Response  ...          Future of Work    1.185
# 10     0.311             365Scores  ...          Communications    1.174
# 11     0.373                  3Box  ...         Data Management    1.119
# 12     0.418           3D-Robotics  ...          Industrial IoT    1.079
# 13     0.311            3sun-Group  ...                 RegTech    1.174
# 14     0.287       40-Partners-Ltd  ...                  Gaming    1.194
# 15     0.337                 42Lab  ...                  Design    1.151
# 16     0.324         4-Antibody-AG  ...                 MedTech    1.162
# 17     0.365               4energy  ...    Climate & Clean Tech    1.127
# 18     0.388                 5Mins  ...         Creator Economy    1.106
# 19     0.363              7bridges  ...        Circular Economy    1.128
# 20     0.427              7digital  ...     Data Infrastructure    1.071
# 21     0.281            7TM-Pharma  ...                Genomics    1.199
# 22     0.321                  8fit  ...              Healthcare    1.166
# 23     0.331         8tracks-Radio  ...           Entertainment    1.157
# 24     0.494                   a55  ...                 FinTech    1.006
# 25     0.317             AarogyaAI  ...           Life Sciences    1.169
# 26     0.377                Abacum  ...           Social Impact    1.116
# 27     0.346             Abacus.AI  ...              Automation    1.143
# 28     0.456        Abacus-e-Media  ...                   Media    1.043
# 29     0.280           ABA-English  ...            Productivity    1.200
# 30     0.429                  ABAX  ...             Procurement    1.069
# 31     0.360               Abcodia  ...                 RegTech    1.131
# 32     0.317                  Abhi  ...                 FemTech    1.169
# 33     0.209        ABK-Biomedical  ...           Life Sciences    1.258
# 34     0.299                Ablynx  ...               Deep Tech    1.184
# 35     0.267    Abogen-Biosciences  ...              Healthcare    1.211
# 36     0.253               Abokado  ...           Supply Chains    1.222
# 37     0.399           AbsolutData  ...   Business Intelligence    1.097
# 38     0.336         Acacia-Pharma  ...               Nutrition    1.152
# 39     0.377           ACAL-Energy  ...        Circular Economy    1.116
# 40     0.387  Accelerated-Payments  ...                 FinTech    1.107
# 41     0.245           AccelerComm  ...  Network Infrastructure    1.229
# 42     0.395           Access-Bank  ...              E-commerce    1.100
# 43     0.412         AccessFintech  ...                 FinTech    1.084
# 44     0.374   Access-Intelligence  ...          Industrial IoT    1.119
# 45     0.304     Accuri-Cytometers  ...                Genomics    1.180
# 46     0.250           Accutrainee  ...             Procurement    1.225
# 47     0.377              AccuVein  ...              Healthcare    1.116
# 48     0.367           Acea-Health  ...                 InfoSec    1.125
# 49     0.254        Acesion-Pharma  ...               Nutrition    1.221
#
#                     name                                     cb_description  \
# 0                  0xKYC  modular knowledge system identity credential m...
# 1           10X-Genomics  create revolutionary dna sequence technology h...
# 2                111Skin  commit positive luxury skincare push boundary ...
# 3                1stdibs  internet company offer marketplace rare desira...
# 4                  1v1Me  application allow user play match favorite vid...
# 5          21sportsgroup  online sport good retailer offer selection run...
# 6              24Symbols  solution read digital book read device interne...
# 7                   2GIS  international technology company develop servi...
# 8      352-Medical-Group  local organisation trust healthcare profession...
# 9           365-Response  response unique software service organisation ...
# 10             365Scores  cross platform application enable user create ...
# 11                  3Box  storage simple secure private design store dat...
# 12           3D-Robotics  make advanced drone technology easily accessib...
# 13            3sun-Group  limited subsidiary provide hydraulic control i...
# 14       40-Partners-Ltd  produce talent broadcaster brand short form fe...
# 15                 42Lab  modular portable affordable biotech laboratory...
# 16         4-Antibody-AG  develop human antibody drug discovery platform...
# 17               4energy  locate nottingham produce cool solution delive...
# 18                 5Mins  s gamified learn platform design help employee...
# 19              7bridges  smart logistic platform deliver visibility con...
# 20              7digital  global leader end end digital music solution c...
# 21            7TM-Pharma  biotech company discover develop drug primary ...
# 22                  8fit  app help build healthy habit life simple solut...
# 23         8tracks-Radio  internet radio social network streams user cur...
# 24                   a55  developer financial underwriting platform offe...
# 25             AarogyaAI  aarogyaai artificial intelligence base softwar...
# 26                Abacum  abacum saas help finance team deliver business...
# 27             Abacus.AI  artificial intelligence research cloud service...
# 28        Abacus-e-Media  abacus e medium bring digital expertise indust...
# 29           ABA-English  lead learn student worldwide headquarter talen...
# 30                  ABAX  developer supplier tracker system software tec...
# 31               Abcodia  biotechnology company focus discovery validati...
# 32                  Abhi  abhi financial wellness platform provide emplo...
# 33        ABK-Biomedical  combine clinical market biomaterial specialize...
# 34                Ablynx  ablynx biopharmaceutical company engage discov...
# 35    Abogen-Biosciences  abogen bioscience discovery stage biotechnolog...
# 36               Abokado  own operate chain food bar restaurant offer su...
# 37           AbsolutData  consult orient analytic research firm number c...
# 38         Acacia-Pharma  pharmaceutical company discover develop suppor...
# 39           ACAL-Energy  developer system module consumable chemical ra...
# 40  Accelerated-Payments  accelerated payment enable sme expand grow all...
# 41           AccelerComm  accelercomm exciting semiconductor ip core com...
# 42           Access-Bank  provide banking product service individual bus...
# 43         AccessFintech  accessfintech offer risk management service ba...
# 44   Access-Intelligence  access intelligence b b medium information com...
# 45     Accuri-Cytometers  found address compelling need life scientist l...
# 46           Accutrainee  accutrainee found run solicitor understand leg...
# 47              AccuVein  accuvein specialize vein visualization technol...
# 48           Acea-Health  acea health digital company develop applicatio...
# 49        Acesion-Pharma  acesion developer medical drug design treatmen...
#
#                 industry1  score1             industry2  score2  \
# 0                 RegTech  17.414                Crypto  17.744
# 1                Genomics  16.785         Life Sciences  17.979
# 2                  Beauty  15.619               SexTech  17.938
# 3                 Fashion  16.470            E-commerce  16.604
# 4         Social Networks  18.454         Entertainment  18.530
# 5                 Fashion  16.454            E-commerce  17.474
# 6                  Mobile  19.303                EdTech  19.557
# 7                  Mobile  16.537           Health Tech  16.761
# 8              Healthcare  15.212           Health Tech  16.581
# 9            Productivity  18.048      Circular Economy  18.290
# 10                Esports  16.615         Entertainment  17.342
# 11           Data Storage  15.000      Physical Storage  16.729
# 12           Productivity  16.463               Defense  16.583
# 13                RegTech  17.680              Telecoms  17.925
# 14          Entertainment  17.772       Creator Economy  17.891
# 15               Hardware  17.605         Manufacturing  17.814
# 16          Life Sciences  17.120               MedTech  17.926
# 17              GreenTech  17.378  Climate & Clean Tech  17.538
# 18        Creator Economy  16.647        Future of Work  16.929
# 19         Industrial IoT  17.269      Circular Economy  17.291
# 20                  Media  16.021              Telecoms  16.667
# 21         Gut Microbiome  17.490         Life Sciences  17.872
# 22  Happiness & Wellbeing  16.456      Sport & Wellness  17.059
# 23        Creator Economy  16.319       Social Networks  17.484
# 24                   DeFi  15.111               RegTech  15.474
# 25            Health Tech  17.420               MedTech  18.114
# 26          Social Impact  17.104          Productivity  17.236
# 27       Physical Storage  17.611            Automation  17.633
# 28        Creator Economy  15.724                Design  16.260
# 29                 EdTech  16.984  Economic Empowerment  18.332
# 30          Supply Chains  15.842             Logistics  16.394
# 31          Life Sciences  17.381               MedTech  17.447
# 32   Economic Empowerment  17.032       Human Resources  17.653
# 33                MedTech  18.563         Life Sciences  19.676
# 34          Life Sciences  17.359                  Nano  17.805
# 35          Life Sciences  17.109              Genomics  17.412
# 36        Food & Beverage  18.154      Circular Economy  18.332
# 37         Industrial IoT  16.686            Automation  16.748
# 38  Happiness & Wellbeing  16.438            Healthcare  17.457
# 39   Climate & Clean Tech  16.669             GreenTech  16.878
# 40   Economic Empowerment  16.201               FinTech  17.011
# 41            5G Networks  17.776              Telecoms  18.440
# 42               Payments  16.298               FinTech  16.580
# 43                   DeFi  16.773               FinTech  16.852
# 44                RegTech  16.945              Telecoms  17.075
# 45          Life Sciences  17.762             Analytics  18.205
# 46              LegalTech  16.638             InsurTech  18.815
# 47                MedTech  16.181           Health Tech  16.699
# 48            Health Tech  16.496            Healthcare  17.061
# 49             Healthcare  18.792             Nutrition  18.974
#
#                  industry3  score3
# 0                 Security  17.834
# 1                Deep Tech  18.731
# 2    Happiness & Wellbeing  17.994
# 3          Creator Economy  16.879
# 4                   Gaming  18.887
# 5         Sport & Wellness  17.722
# 6               FamilyTech  19.835
# 7                 Telecoms  16.852
# 8                  MedTech  17.797
# 9          Developer Tools  18.345
# 10          Communications  17.914
# 11         Data Management  17.196
# 12   Business Intelligence  16.806
# 13          Industrial IoT  18.334
# 14                  Gaming  18.522
# 15               Deep Tech  17.952
# 16                Genomics  18.101
# 17       Energy Efficiency  17.965
# 18                  Gaming  17.006
# 19           Supply Chains  17.325
# 20           Entertainment  16.737
# 21               Nutrition  18.851
# 22                  Mobile  17.809
# 23           Entertainment  17.890
# 24               LegalTech  15.572
# 25              Healthcare  18.119
# 26         Sharing Economy  17.411
# 27         Cloud Computing  17.683
# 28                   Media  16.507
# 29            Productivity  18.513
# 30             Procurement  16.993
# 31                Genomics  17.695
# 32            Productivity  18.048
# 33             Health Tech  19.727
# 34               Deep Tech  18.612
# 35              Healthcare  18.716
# 36           Supply Chains  18.603
# 37   Business Intelligence  17.244
# 38                  Beauty  17.973
# 39        Circular Economy  17.309
# 40                    DeFi  17.035
# 41  Network Infrastructure  18.703
# 42              E-commerce  16.924
# 43                 RegTech  16.865
# 44            Data Centers  17.344
# 45                 MedTech  18.327
# 46                    DeFi  19.037
# 47              Healthcare  17.478
# 48                 InfoSec  17.190
# 49           Supply Chains  19.197
#
# [50 rows x 25 columns]
